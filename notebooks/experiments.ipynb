# %%
import os
from pathlib import Path
import mlflow
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Генерируем данные

# %%
data = pd.read_csv(Path("..\\data\\prepare_data\\iris_prepare.csv")).drop(columns=["Unnamed: 0"])
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  target
# 0       Iris-setosa       0
# 1       Iris-setosa       0
# 2       Iris-setosa       0
# 3       Iris-setosa       0
# 4       Iris-setosa       0
# ..              ...     ...
# 145  Iris-virginica       2
# 146  Iris-virginica       2
# 147  Iris-virginica       2
# 148  Iris-virginica       2
# 149  Iris-virginica       2
#
# [150 rows x 7 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop(columns = ["Id", "Species"]), data["target"], test_size=0.2, random_state=42)

# %%
# Создаём или выбираем эксперимент
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("Homework_Experiments")



# Проводим 15+ экспериментов
for n_est in [10, 50, 100, 150, 200]:
    for depth in [3, 5, 7, 10, None]:
        with mlflow.start_run():
            params = {"n_estimators": n_est, "max_depth": depth}
            mlflow.log_params(params)

            model = RandomForestClassifier(**params, random_state=42)
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            acc = accuracy_score(y_test, y_pred)
            mlflow.log_metric("accuracy", acc)

            signature = mlflow.models.infer_signature((X_test), model.predict(X_test))
            # Сохраняем модель как артефакт
            mlflow.sklearn.log_model(
                sk_model = model, 
                name = "model",
                registered_model_name="RandomForestClassifier",
                signature=signature,
            )
# Out:
# 2025/12/14 15:54:34 INFO mlflow.tracking.fluent: Experiment with name 'Homework_Experiments' does not exist. Creating a new experiment.
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/12/14 15:54:38 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Successfully registered model 'RandomForestClassifier'.
# 2025/12/14 15:54:38 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 1
# Created version '1' of model 'RandomForestClassifier'.
# 🏃 View run unruly-hare-839 at: http://127.0.0.1:5000/#/experiments/1/runs/809baa43a6e94ef59ff84f5377ce012a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/12/14 15:54:41 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:54:41 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 2
# Created version '2' of model 'RandomForestClassifier'.
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run rogue-crow-961 at: http://127.0.0.1:5000/#/experiments/1/runs/99c19201c84940259803c01c9b62fc80
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 2025/12/14 15:54:44 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:54:44 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 3
# Created version '3' of model 'RandomForestClassifier'.
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run nimble-kite-212 at: http://127.0.0.1:5000/#/experiments/1/runs/570656cc6d1548428dbace4013ef1463
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 2025/12/14 15:54:47 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:54:47 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 4
# Created version '4' of model 'RandomForestClassifier'.
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run resilient-fish-725 at: http://127.0.0.1:5000/#/experiments/1/runs/a8473453dd4f4609947e3cb7f468d8b7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 2025/12/14 15:54:50 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:54:50 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 5
# Created version '5' of model 'RandomForestClassifier'.
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run adventurous-goose-20 at: http://127.0.0.1:5000/#/experiments/1/runs/083967da84764a34b3fbed2b1edce68b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 2025/12/14 15:54:53 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:54:53 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 6
# Created version '6' of model 'RandomForestClassifier'.
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run fearless-shrike-714 at: http://127.0.0.1:5000/#/experiments/1/runs/c30e1208b2e54f31966a7354bfbf24cd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 2025/12/14 15:54:56 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:54:56 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 7
# Created version '7' of model 'RandomForestClassifier'.
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run mysterious-mole-776 at: http://127.0.0.1:5000/#/experiments/1/runs/90fafddd8efa4cda9349035cade1cd7c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 2025/12/14 15:54:59 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:54:59 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 8
# Created version '8' of model 'RandomForestClassifier'.
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run victorious-snipe-567 at: http://127.0.0.1:5000/#/experiments/1/runs/16c47943519e4f0988d828960a8d6731
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 2025/12/14 15:55:01 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:01 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 9
# Created version '9' of model 'RandomForestClassifier'.
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run smiling-mule-413 at: http://127.0.0.1:5000/#/experiments/1/runs/3c6cd42e11814c069673942eab50d2f1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 2025/12/14 15:55:04 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:04 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 10
# Created version '10' of model 'RandomForestClassifier'.
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run learned-goose-412 at: http://127.0.0.1:5000/#/experiments/1/runs/b0f9d32f963f4ce49aabd8186a6ad70f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 2025/12/14 15:55:07 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:07 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 11
# Created version '11' of model 'RandomForestClassifier'.
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run loud-slug-66 at: http://127.0.0.1:5000/#/experiments/1/runs/5785ab6ea72e447f91914c7f5ce280fa
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 2025/12/14 15:55:10 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:10 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 12
# Created version '12' of model 'RandomForestClassifier'.
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run clean-asp-664 at: http://127.0.0.1:5000/#/experiments/1/runs/1d1c4c11c4e64acd8df4f18495c2d874
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 2025/12/14 15:55:13 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:13 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 13
# Created version '13' of model 'RandomForestClassifier'.
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run rare-bee-989 at: http://127.0.0.1:5000/#/experiments/1/runs/43e3e33adc9b4e05b9245588bab81435
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 2025/12/14 15:55:15 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:15 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 14
# Created version '14' of model 'RandomForestClassifier'.
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run judicious-shrew-480 at: http://127.0.0.1:5000/#/experiments/1/runs/4cb09c356f1d480b9c439b763b6cd9ea
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 2025/12/14 15:55:18 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:18 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 15
# Created version '15' of model 'RandomForestClassifier'.
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run amusing-gull-467 at: http://127.0.0.1:5000/#/experiments/1/runs/54b6d05923aa45e5936d3e5e2809f417
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# 2025/12/14 15:55:21 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:21 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 16
# Created version '16' of model 'RandomForestClassifier'.
# 🏃 View run capable-rat-151 at: http://127.0.0.1:5000/#/experiments/1/runs/b2676704a48f4774b0e4544427bb88bd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/12/14 15:55:24 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:24 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 17
# Created version '17' of model 'RandomForestClassifier'.
# 🏃 View run kindly-boar-470 at: http://127.0.0.1:5000/#/experiments/1/runs/95e3aaa51e224f45944418b87d503b59
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/12/14 15:55:27 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:27 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 18
# Created version '18' of model 'RandomForestClassifier'.
# 🏃 View run luxuriant-trout-443 at: http://127.0.0.1:5000/#/experiments/1/runs/2c32e86286a14f6c8a7d01db0cbec72f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/12/14 15:55:30 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:30 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 19
# Created version '19' of model 'RandomForestClassifier'.
# 🏃 View run beautiful-chimp-432 at: http://127.0.0.1:5000/#/experiments/1/runs/dd12a6ce1210441899dcc200e79ec0f2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/12/14 15:55:33 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:33 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 20
# Created version '20' of model 'RandomForestClassifier'.
# 🏃 View run powerful-turtle-883 at: http://127.0.0.1:5000/#/experiments/1/runs/5067f723f50b4ac58acac08faac474e7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/12/14 15:55:36 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:36 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 21
# Created version '21' of model 'RandomForestClassifier'.
# 🏃 View run placid-crow-72 at: http://127.0.0.1:5000/#/experiments/1/runs/f2e3747043b54ce294217742217109a3
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/12/14 15:55:39 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:39 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 22
# Created version '22' of model 'RandomForestClassifier'.
# 🏃 View run skillful-kit-802 at: http://127.0.0.1:5000/#/experiments/1/runs/6152e801495449429cd1c70af86b6e20
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/12/14 15:55:41 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:41 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 23
# Created version '23' of model 'RandomForestClassifier'.
# 🏃 View run shivering-hawk-872 at: http://127.0.0.1:5000/#/experiments/1/runs/0dc76a25a0f24b3cb5c86fd39f80576b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/12/14 15:55:44 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:44 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 24
# Created version '24' of model 'RandomForestClassifier'.
# 🏃 View run placid-turtle-101 at: http://127.0.0.1:5000/#/experiments/1/runs/3ca19872397c4fb2aee7d39896a1b943
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# d:\programming\ITMO\engineering-practices-ml\.venv\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/12/14 15:55:47 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'RandomForestClassifier' already exists. Creating a new version of this model...
# 2025/12/14 15:55:47 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier, version 25
# 🏃 View run spiffy-ant-236 at: http://127.0.0.1:5000/#/experiments/1/runs/37ce404eaa5647ddb090edb45f31544e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
# Created version '25' of model 'RandomForestClassifier'.
